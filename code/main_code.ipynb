# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a more comprehensive dataset spanning from 2001 to 2024
data = {
    'Year': [
        *range(2001, 2025),
        *range(2001, 2025),
        *range(2001, 2025),
        *range(2001, 2025),
        *range(2001, 2025)
    ],
    'Species': (
        ['Asian Elephant'] * 24 +
        ['Bengal Tiger'] * 24 +
        ['Indian Rhino'] * 24 +
        ['Snow Leopard'] * 24 +
        ['King Cobra'] * 24
    ),
    'Abundance': (
        [150 + i*6 for i in range(24)] +
        [90 + i*8 for i in range(24)] +
        [70 + i*7 for i in range(24)] +
        [55 + i*4 for i in range(24)] +
        [35 + i*5 for i in range(24)]
    ),
    'Region': (
        ['Region A'] * 24 +
        ['Region B'] * 24 +
        ['Region C'] * 24 +
        ['Region D'] * 24 +
        ['Region E'] * 24
    )
}

df = pd.DataFrame(data)

print(df.head())

print(df.isnull().sum())

print(df.describe())

plt.figure(figsize=(14, 7))
sns.lineplot(x='Year', y='Abundance', hue='Species', data=df, marker="o")
plt.title('Trends in Species Abundance Over Time')
plt.xlabel('Year')
plt.ylabel('Abundance')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(14, 7))
sns.countplot(y='Region', hue='Species', data=df)
plt.title('Distribution of Species Across Different Regions')
plt.xlabel('Count')
plt.ylabel('Region')
plt.grid(True)
plt.show()

total_abundance = df.groupby('Year')['Abundance'].sum().reset_index()

plt.figure(figsize=(14, 7))
sns.barplot(x='Year', y='Abundance', data=total_abundance, palette='viridis')
plt.title('Total Abundance of All Species by Year')
plt.xlabel('Year')
plt.ylabel('Total Abundance')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

plt.figure(figsize=(14, 7))
sns.boxplot(x='Species', y='Abundance', data=df)
plt.title('Box Plot of Abundance by Species')
plt.xlabel('Species')
plt.ylabel('Abundance')
plt.grid(True)
plt.show()

pivot_table = df.pivot(index='Year', columns='Species', values='Abundance')
plt.figure(figsize=(14, 7))
sns.heatmap(pivot_table, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Heatmap of Species Abundance Over Time')
plt.xlabel('Species')
plt.ylabel('Year')
plt.show()

plt.figure(figsize=(14, 7))
sns.scatterplot(x='Year', y='Abundance', hue='Species', data=df, s=100)
plt.title('Scatter Plot of Abundance vs Year for Each Species')
plt.xlabel('Year')
plt.ylabel('Abundance')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
# Out:
#    Year         Species  Abundance    Region
# 0  2001  Asian Elephant        150  Region A
# 1  2002  Asian Elephant        156  Region A
# 2  2003  Asian Elephant        162  Region A
# 3  2004  Asian Elephant        168  Region A
# 4  2005  Asian Elephant        174  Region A
# Year         0
# Species      0
# Abundance    0
# Region       0
# dtype: int64
#               Year   Abundance
# count   120.000000  120.000000
# mean   2012.500000  149.000000
# std       6.951211   64.443318
# min    2001.000000   35.000000
# 25%    2006.750000   98.000000
# 50%    2012.500000  139.500000
# 75%    2018.250000  199.000000
# max    2024.000000  288.000000
# <ipython-input-2-2bb40f1708d5>:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='Abundance', data=total_abundance, palette='viridis')
